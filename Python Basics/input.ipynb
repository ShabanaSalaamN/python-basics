# %% [markdown]
# #INPUT AND OUTPUT

# %%
name = input("Enter your name: ")
print(name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name = input("Enter your name: ")
#       2 print(name)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# * input()waits for user input
# * whatever the user types becomes a string
# * the value is stored in the variable name

# %%
name = input("Enter your name: ")
print("His name is:" ,name)
print(type(name))

age =input("Enter your age:")
print(type(age))
# Out:
# His name is: NIYAS
# <class 'str'>
# <class 'str'>

# %%
age =int(input("Enter your age:"))
print("He is",age,"year old")
# Out:
# He is 30 year old

# %% [markdown]
# #Converting input in to integer

# %%
age=int(input("Enter your age: "))
print(age)
print(type(age))
# Out:
# 30
# <class 'int'>

# %%
height=float(input("Enter your height:" ))
print(height)
print(type(height))
# Out:
# 163.25
# <class 'float'>

# %%
num1=input("Enter first number:" )
num2=input("Enter your second number:" )
sum_result=num1 + num2
print("sum =" , sum_result)
# Out:
# sum = 8635

# %%
num1=int(input("Enter first number:" ))
num2=int(input("Enter second number:" ))
sum_result= num1 + num2
print("sum =" , sum_result)
# Out:
# sum = 121

# %%
num1=float(input("Enter first number:" ))
num2=float(input("Enter second number:" ))
sum_result= num1 + num2
print("sum =", sum_result)
# Out:
# sum = 102.1

# %% [markdown]
# #String format

# %%
name= "ammaar"
age = 9

print("Name is", name , "and age is ", age)
print("Hello" + name)
print("my name is {} and I am {} years old.".format(name,age))
print("my name is {0} and I am {1}year old.".format(name,age))
print("My name is {n} and I am {a}year old.".format(n=name, a=age))
print(f"{name} is {age} year old.")
# Out:
# Name is ammaar and age is  9
# Helloammaar
# my name is ammaar and I am 9 years old.
# my name is ammaar and I am 9year old.
# My name is ammaar and I am 9year old.
# ammaar is 9 year old.

# %% [markdown]
# #Expression inside f-string

# %%
a=10
b=20
print(f"sum = {a+b}")
print(f"multiplication = {a * b}")
# Out:
# sum = 30
# multiplication = 200

# %%
a=145
b=57
print(f"sum = {a+b}")
print(f"multiplication = {a * b}")
# Out:
# sum = 202
# multiplication = 8265

# %%
pi=3.1415926535

print(f"value pf pi = {pi:.2f}")    #.2f means 2 digital after decimal
# Out:
# value pf pi = 3.14

# %%
b=678.5432678

print(f"value of b {b:.2f}")
# Out:
# value of b 678.54

# %% [markdown]
# #percentage formating

# %%
mark = 87.5677

print(f"percentage = {mark:.1f}%")
# Out:
# percentage = 87.6%

# %% [markdown]
# #Conditional statement

# %% [markdown]
# #if

# %%
age= 20

if age>= 18:
    print("you are eligible to vote")
# Out:
# you are eligible to vote

# %%
age= 10

if age>= 18:
    print("your are eligible to vote")

# %%
num=int(input("Enter a number: "))

if num > 0:
    print("positive number")
# Out:
# positive number

# %% [markdown]
# #if- else

# %%
age=int(input("enetr your age: "))

if age> 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Not eligible to vote

# %%
mark= int(input("enetr your mark:" ))

if mark> 40:
    print("your are pass")
else:
    print("yuor failed")
# Out:
# yuor failed

# %%
num=int(input("Enter your number: "))

if num % 2 == 0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %% [markdown]
# #Elif

# %%
a,b = 10,20
if a % 2 ==0:
    print("equal")
elif a>b:
    print("a is bigger")
else: 
    print("b is bigeger")
# Out:
# b is bigeger

# %%
signal= input("enter signal colour")
if signal == "red":
    print("stop")
elif signal == "yellow":
    print("slow")
else:
    print("go")
# Out:
# go

# %%
mark = int(input("enter your mark"))
if mark >= 90:
    print("A grade")
elif mark >= 80:
    print("B grade")
elif mark >= 70:
    print("c grade")
elif mark >= 60:
    print("D grade")
else:
    print("failed")
# Out:
# failed

# %% [markdown]
# #Nested if

# %%
username= "admin"
password= "1234"
if username == "admin":
    if password == "1234":
        print("login succesfully")
    else:
        print("wrong password")
else:
    print("invalid username")
# Out:
# login succesfully

# %%
mark=int(input("mark is"))
income=int(input("income is"))
if mark >= 80:
    if income <=20000:
        print("eligible")
    else:
        print("not eligible")
else:
    print("not eligibe")
# Out:
# not eligibe

# %%
mark = 89
income = 18000

if mark >= 80 and income >= 20000:
         print("eligible")
else: 
    print("not eligible")
# Out:
# not eligible

# %%
num=int(input("number"))

if num >0:
    print("positive")

else: num<0
print("negative")
# Out:
# positive
# negative

# %%
num =int(input("check number"))

if num % 2 == 0:
    print(f"{num} is an even number")

else:
    print(f"{num} is an odd number")
# Out:
# 77 is an odd number

# %%
a=int(input("this is the one number"))
b=int(input("this is ithe second number"))
if a>b:
    print(f"{54} is largest number")

else: b>a
print(f"{67} is largest number")
# Out:
# 67 is largest number

# %%
num=int(input("check a number"))
if num % 10 ==0 and num % 5 ==0:
      print(f"{num} is divided by 5 and 10")

else:
    print(f"{num}is not divided by 5 and 10")
# Out:
# 50 is divided by 5 and 10

# %%
year=int(input("leap year"))
if year % 4==0 and year % 100 !=0 or year % 400 ==0:
        print(f"{year} is leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2025 is not a leap year

# %%
letter= input("check the letter")
if letter in"aeiou":
    print(f"{letter} is a vowel")

else:
    print(f"{letter} is conconant")
# Out:
# f is conconant

# %%
num=int(input("enetr a number"))
if num <10:
    print(f"{num} is a single digit number")
elif  num<100:
    print(f"{num} is a double digit number")   
else:
    print(f"{num} triple digit number")
# Out:
# 7 is a single digit number

# %%
name=input("enter a name")
age =int(input("enter a number"))
if age >=18:
    print(f"{name} your eligible to vote")

else:
    print(f"{name} your not eligibe to vote")
# Out:
# niyas your eligible to vote

# %%
num= int(input("enter a number"))
if num ==0:
    print(f"{num} is zero")
elif num<0:
    print(f"{num} is a negative number")  

else:
    print(f"{num} is positive number")
# Out:
# 0 is zero

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
if num1>num2 and num1>num3:
    print(f"{num1} is largest number")
elif num2>num1 and num2>num3:
    print(f"{num2} is largest number")
else:
    print(f"{num3} is largest number")
# Out:
# 789 is largest number

# %%
mark=int(input("enter your mark"))
if mark>=90:
    print("A GRADE")
elif mark>=80:
    print("B GRADE")
elif mark>=70:
    print("C GRADE")    
elif mark >=60:
    print("D GRADE") 
else:
    print("FAILED")
# Out:
# C GRADE

# %%
year =int(input("enter a year"))
if year % 100==0:
     print(f"{year} is a century year")

else:
    print(f"{year} is not century year")
# Out:
# 3000 is a century year

# %%
alphabet =input("enter a alphabet")
if alphabet.isupper():
    print(f"{alphabet} is in upper case")

elif alphabet.islower():
    print(f"{alphabet} is lower case") 

elif alphabet.isdigit():
    print(f"{alphabet} is a digit")
else:
    print("is sphecial")
# Out:
# is sphecial

# %%
n=int(input("enter a number"))
if int(str(n)[-1]) % 2==0:
    print("last digit is even number")
else:
    print("last digit number is odd")
# Out:
# last digit number is odd

# %%
score=int(input("enter a mark"))
if score>=85:
    print("pass with distinction")
elif score>=40 and score<=84:
    print("pass")
else:
    print("failed")
# Out:
# failed

# %%
num=int(input("enter a number"))
if num % 2==0 and num>10:
    print("even and >10")

else:
    print("no")
# Out:
# no

# %%
age=int(input("enter a age"))
if age>=13 and age<=19:
    print("teen")

else:
    print("Not teen")
# Out:
# Not teen

# %%
num1=int(input("enter first number"))
num2=int(input("enter a second number"))
num3=int(input("enter the third number"))
if num1==num2 and num2==num3 or num3==num1:
    print("all are equal")

elif num1==num2 or num2==num3 or num1==num3:
    print("any two is equal")

else:
    print("all are different")
# Out:
# all are equal

# %%
num=int(input("enter a number"))
if num%3==0 and num%5==0:
        print("fizzbuzz")
elif num%3==0:
        print("fizz")   
elif num%5==0:
        print("buzz")    
else:
        print("num")
# Out:
# fizzbuzz

# %%
string=input("enter a string")
if len(string)==0:
    print("empty")
else:
    print("not empty")
# Out:
# not empty

# %%
num1=int(input("enter first number"))
num2=int(input("enter second number")) 
if num1%2==0 and num2% 2==0:
    print("both even")
elif num1%2==0 or num2% 2==0:
    print("one even")   
else:print("none even")
# Out:
# none even
