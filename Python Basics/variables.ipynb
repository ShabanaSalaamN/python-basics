# %%
name , age , country , ranking , jersey  , club = "neymar" , 34 , "brazil" , 6 , 10 , "santos_FC"
print(name)
print(club)
print(country)
jersey
# Out:
# neymar
# santos_FC
# brazil
# 10

# %% [markdown]
# ## Rules for naming variables

# %% [markdown]
# 1.Must start with a letter or underscore`_`
#
# 2.Cannot start with a number
#
# 3.Can contain letters,digits,and underscore
#
# 4.Case-sensitive(`Name`=! `name`)
#
# 5.Should not use python keywords(`if`,`for`,`class`,etc.)

# %% [markdown]
# ##variables Assignment in python

# %%
x=10           #assigns the integer
name = "Sam"
is_valid = False
print(name)
# Out:
# Sam

# %%
x= 10
name = "shabana"
_price =99.9
is_active = True
print(name,_price,type(x))
# Out:
# shabana 99.9 <class 'int'>

# %%
name = "Emin"
name
print(name)
print("name")
print("my name is",name)
print("my name is",name,"and everyone call me",type(name))
# Out:
# Emin
# name
# my name is Emin
# my name is Emin and everyone call me <class 'str'>

# %%
y= 37.5   # decimal number
print(y,type(y))
# Out:
# 37.5 <class 'float'>
